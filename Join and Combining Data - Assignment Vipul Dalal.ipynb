# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Question 1.) Write a Pandas program to join the two given data frames along rows and assign all data.

# %%
student_data1 = pd.DataFrame({'student_id': ['S1', 'S2', 'S3', 'S4', 'S5'],
                              'name': ['Danniella Fenton', 'Ryder Storey', 'Bryce Jensen',
                                       'Ed Bernal', 'Kwame Morin'],
                              'marks': [200, 210, 190, 222, 199]})
student_data2 = pd.DataFrame({'student_id': ['S4', 'S5', 'S6', 'S7', 'S8'],
                              'name': ['Scarlette Fisher', 'Carla Williamson', 'Dante Morse',
                                       'Kaiser William', 'Madeeha Preston'],
                              'marks': [201, 200, 198, 219, 201]})

join_df = pd.concat([student_data1, student_data2])
join_df
# Out:
#   student_id              name  marks
# 0         S1  Danniella Fenton    200
# 1         S2      Ryder Storey    210
# 2         S3      Bryce Jensen    190
# 3         S4         Ed Bernal    222
# 4         S5       Kwame Morin    199
# 0         S4  Scarlette Fisher    201
# 1         S5  Carla Williamson    200
# 2         S6       Dante Morse    198
# 3         S7    Kaiser William    219
# 4         S8   Madeeha Preston    201

# %% [markdown]
# # Question 2.) Write a Pandas program to join the two given dataframes along rows and merge with another dataframe along the common column id.

# %%
student_data1 = pd.DataFrame({'student_id': ['S1', 'S2', 'S3', 'S4', 'S5'],
                              'name': ['Danniella Fenton', 'Ryder Storey', 'Bryce Jensen',
                                       'Ed Bernal', 'Kwame Morin'],
                              'marks': [200, 210, 190, 222, 199]})
student_data2 = pd.DataFrame({'student_id': ['S4', 'S5', 'S6', 'S7', 'S8'],
                              'name': ['Scarlette Fisher', 'Carla Williamson', 'Dante Morse',
                                       'Kaiser William', 'Madeeha Preston'],
                              'marks': [201, 200, 198, 219, 201]})
exam_data = pd.DataFrame({'student_id': ['S1', 'S2', 'S3', 'S4', 'S5', 'S7', 'S8', 'S9', 'S10', 'S11', 'S12', 'S13'],
                          'exam_id': [23, 45, 12, 67, 21, 55, 33, 14, 56, 83, 88, 12]})


# Joining first two said data frames along rows

join_df = pd.concat([student_data1, student_data2])
join_df
# Out:
#   student_id              name  marks
# 0         S1  Danniella Fenton    200
# 1         S2      Ryder Storey    210
# 2         S3      Bryce Jensen    190
# 3         S4         Ed Bernal    222
# 4         S5       Kwame Morin    199
# 0         S4  Scarlette Fisher    201
# 1         S5  Carla Williamson    200
# 2         S6       Dante Morse    198
# 3         S7    Kaiser William    219
# 4         S8   Madeeha Preston    201

# %%
# Now joining the join_df and exam_data along the common column student_id

New_df = pd.merge(join_df, exam_data, on='student_id')
New_df
# Out:
#   student_id              name  marks  exam_id
# 0         S1  Danniella Fenton    200       23
# 1         S2      Ryder Storey    210       45
# 2         S3      Bryce Jensen    190       12
# 3         S4         Ed Bernal    222       67
# 4         S4  Scarlette Fisher    201       67
# 5         S5       Kwame Morin    199       21
# 6         S5  Carla Williamson    200       21
# 7         S7    Kaiser William    219       55
# 8         S8   Madeeha Preston    201       33

# %% [markdown]
# ### Importing DataFrame "matches.csv" for further questions

# %%
df = pd.read_csv('matches.csv')
df.head(2)
# Out:
#    id  season       city        date                team1  \
# 0   1    2017  Hyderabad  2017-04-05  Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06       Mumbai Indians
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
#
#    result  dl_applied                  winner  win_by_runs  win_by_wickets  \
# 0  normal           0     Sunrisers Hyderabad           35               0
# 1  normal           0  Rising Pune Supergiant            0               7
#
#   player_of_match                                      venue         umpire1  \
# 0    Yuvraj Singh  Rajiv Gandhi International Stadium, Uppal     AY Dandekar
# 1       SPD Smith    Maharashtra Cricket Association Stadium  A Nand Kishore
#
#     umpire2  umpire3
# 0  NJ Llong      NaN
# 1    S Ravi      NaN

# %% [markdown]
# # Question 3.) Split the dataset into 2 parts, first containing top 5 rows and the other containing next 5 rows. Print the shape and then append the 1st dataframe to the end of the 2nd dataframe.

# %%
top5 = df.iloc[:5,:]
next5 = df.iloc[5:10,:]

print(top5.shape)
print(next5.shape)
# Out:
# (5, 18)
# (5, 18)

# %%
apnd = next5.append(top5)
apnd
# Out:
# C:\Users\acer\AppData\Local\Temp\ipykernel_9792\1354288197.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   apnd = next5.append(top5)
#    id  season       city        date                        team1  \
# 5   6    2017  Hyderabad  2017-04-09                Gujarat Lions
# 6   7    2017     Mumbai  2017-04-09        Kolkata Knight Riders
# 7   8    2017     Indore  2017-04-10  Royal Challengers Bangalore
# 8   9    2017       Pune  2017-04-11             Delhi Daredevils
# 9  10    2017     Mumbai  2017-04-12          Sunrisers Hyderabad
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
# ...

# %% [markdown]
# # Question 4.) Split the dataset into 2 parts, first containing top 5 rows and the other containing next 5 rows. Print the shape and then concat them based on columns.

# %%
top5 = df.iloc[:5,:]
next5 = df.iloc[5:10,:]

print(top5.shape)
print(next5.shape)
# Out:
# (5, 18)
# (5, 18)

# %%
concat = pd.concat([top5, next5], axis = 1)
concat.head(10)
# Out:
#     id  season       city        date                        team1  \
# 0  1.0  2017.0  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1  2.0  2017.0       Pune  2017-04-06               Mumbai Indians
# 2  3.0  2017.0     Rajkot  2017-04-07                Gujarat Lions
# 3  4.0  2017.0     Indore  2017-04-08       Rising Pune Supergiant
# 4  5.0  2017.0  Bangalore  2017-04-08  Royal Challengers Bangalore
# 5  NaN     NaN        NaN         NaN                          NaN
# 6  NaN     NaN        NaN         NaN                          NaN
# 7  NaN     NaN        NaN         NaN                          NaN
# 8  NaN     NaN        NaN         NaN                          NaN
# 9  NaN     NaN        NaN         NaN                          NaN
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# ...

# %% [markdown]
# # Question 5.) Split the dataset into 2 parts based on the columns, print their shape and then join them with the columns of 1st dataframe being displayed after the columns of 2nd dataframe.

# %%
first_col = df.iloc[:,:9]
last_col = df.iloc[:,9:19]
print(first_col.shape)
print(last_col.shape)
# Out:
# (636, 9)
# (636, 9)

# %%
res_join = last_col.join(first_col)
res_join.head()
# Out:
#    dl_applied                       winner  win_by_runs  win_by_wickets  \
# 0           0          Sunrisers Hyderabad           35               0
# 1           0       Rising Pune Supergiant            0               7
# 2           0        Kolkata Knight Riders            0              10
# 3           0              Kings XI Punjab            0               6
# 4           0  Royal Challengers Bangalore           15               0
#
#   player_of_match                                      venue         umpire1  \
# 0    Yuvraj Singh  Rajiv Gandhi International Stadium, Uppal     AY Dandekar
# 1       SPD Smith    Maharashtra Cricket Association Stadium  A Nand Kishore
# 2         CA Lynn     Saurashtra Cricket Association Stadium     Nitin Menon
# 3      GJ Maxwell                     Holkar Cricket Stadium    AK Chaudhary
# 4       KM Jadhav                      M Chinnaswamy Stadium             NaN
#
#          umpire2  umpire3  id  season       city        date  \
# ...
